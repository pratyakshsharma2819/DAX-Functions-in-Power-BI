# %% [markdown]
# Q1.1.Create a calculated column Total price using Quantity  and unit price .
#
#     ->Total price = 'Sheet1'[Quantity] * 'Sheet1'[UnitPrice]

# %% [markdown]
# 2.Create a calculated column Discounted price .
#
#     ->Discounted price = 'Sheet1'[Quantity] * 'Sheet1'[UnitPrice] * (1 - 'Sheet1'[Discount])

# %% [markdown]
# 3. Create a measure Avg. Order Value?
#
#     ->Avg. Order Value =
# DIVIDE(
#     SUM('Sheet1'[Total price]),
#     DISTINCTCOUNT('Sheet1'[OrderID]),
#     0
# )

# %% [markdown]
# 4. Using DAX, create a measure that calculates cumulative Year-to-Date (YTD) Sales based on the Order Date
#
#     ->YTD Sales =
# TOTALYTD(
#     SUM('Sheet1'[Total price]),
#     'Sheet1'[OrderDate]
# )

# %% [markdown]
# 5. Using DAX, create a measure to rank each product according to its Total Sales, with the highest-selling product ranked first.
#
#     ->Product Sales Rank =
# RANKX(
#     ALL('Sheet1'[ProductID]),
#     SUM('Sheet1'[Total price]),
#     ,
#     DESC,
#     Dense
# )

# %% [markdown]
# 6. Create a calculated column classifying orders as “High Value” if sales > 2000, else “Low Value”.
#
#     ->Order Value Class =
# IF(
#     'Sheet1'[Discounted price] > 2000,
#     "High Value",
#     "Low Value"
# )

# %% [markdown]
# 7. Create a measure to calculate total sales from the Online channel only.
#
#     ->Online Sales =
# CALCULATE(
#     SUM('Sheet1'[Total price]),
#     'Sheet1'[SalesChannel] = "Online"
# )

# %% [markdown]
# 8. Create a measure called "Date Difference" that calculates the number of days between the latest  Order Date and today's date using the DATEDIFF function.
#
#     ->Date Difference =
# DATEDIFF(
#     MAX('Sheet1'[OrderDate]),
#     TODAY(),
#     DAY
# )
